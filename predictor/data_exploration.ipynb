# %%
import pandas as pd

# %%
df = pd.read_csv("data/cleaned_merged_seasons.csv")
# Out:
# /var/folders/yv/683h12gj4mdc5txzm0lh6j0h0000gn/T/ipykernel_84939/625615907.py:1: DtypeWarning: Columns (2,3,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/cleaned_merged_seasons.csv")

# %%
for i in df['season_x'].unique():
    print(i)
    print("NA values sum", df[df['season_x'] == i]['expected_goals'].isna().sum())
    print()
# Out:
# 2016-17
# NA values sum 23679
#
# 2017-18
# NA values sum 22467
#
# 2018-19
# NA values sum 21790
#
# 2019-20
# NA values sum 22560
#
# 2020-21
# NA values sum 24365
#
# 2021-22
# NA values sum 25447
#
# 2022-23
# NA values sum 0
#
# 2023-24
# NA values sum 0
#
# 2024-25
# NA values sum 0
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
season_21 = df[df['season_x'] == '2016-17']
for i in season_21:
    print(i, season_21[i].isna().sum())
# Out:
# season_x 0
# name 0
# position 23679
# team_x 23679
# assists 0
# bonus 0
# bps 0
# clean_sheets 0
# creativity 0
# element 0
# fixture 0
# goals_conceded 0
# goals_scored 0
# ict_index 0
# influence 0
# kickoff_time 0
# minutes 0
# opponent_team 0
# opp_team_name 0
# own_goals 0
# penalties_missed 0
# penalties_saved 0
# red_cards 0
# round 0
# saves 0
# selected 0
# team_a_score 0
# team_h_score 0
# threat 0
# total_points 0
# transfers_balance 0
# transfers_in 0
# transfers_out 0
# value 0
# was_home 0
# yellow_cards 0
# expected_goals 23679
# expected_assists 23679
# expected_goals_conceded 23679
# GW 0
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
mohamed_salah = df[df['name'] == 'Mohamed Salah']
mohamed_salah["element"].unique()
# Out:
# array([234, 254, 233, 283, 308, 328])

# %%
#element does not persist across seasons, name only reliable variable
# (but should standardize)

# %%
df.columns
# Out:
# Index(['season_x', 'name', 'position', 'team_x', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
#        'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
#        'opponent_team', 'opp_team_name', 'own_goals', 'penalties_missed',
#        'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
#        'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'expected_goals', 'expected_assists',
#        'expected_goals_conceded', 'GW'],
#       dtype='object')

# %%
df["opp_team_name"].unique()
# Out:
# array(['Chelsea', 'Spurs', 'Liverpool', 'Southampton', 'West Ham',
#        'Leicester', 'Stoke', 'Man Utd', 'Arsenal', 'Man City', 'Hull',
#        'Sunderland', 'Watford', 'Everton', 'Bournemouth', 'Swansea',
#        'West Brom', 'Burnley', 'Crystal Palace', 'Middlesbrough',
#        'Brighton', 'Huddersfield', 'Newcastle', 'Fulham', 'Cardiff',
#        'Wolves', 'Sheffield Utd', 'Norwich', 'Aston Villa', 'Leeds',
#        'Brentford', "Nott'm Forest", 'Luton', nan], dtype=object)

# %%
df["opponent_team"].unique()
# Out:
# array([ 4, 17,  9, 13, 20,  8, 14, 11,  1, 10,  7, 15, 18,  6,  2, 16, 19,
#         3,  5, 12])

# %%
df["was_home"].unique()
# Out:
# array([False,  True])

# %%
watford = df[df["opp_team_name"] == "Watford"]
watford["opponent_team"].unique()
# Out:
# array([18])

# %%
team_h_score_nan = df[df["team_h_score"].isna()]
# Out:
#       season_x                                         name position team_x  \
# 83810  2019-20                              John Stones 207      NaN    NaN
# 83812  2019-20                              David Silva 219      NaN    NaN
# 83814  2019-20                              Bukayo Saka 541      NaN    NaN
# 83816  2019-20                             Sead Kolasinac 3      NaN    NaN
# 83836  2019-20                                Bernd Leno 14      NaN    NaN
# 83842  2019-20                              Kyle Walker 203      NaN    NaN
# 83845  2019-20                 Pierre-Emerick Aubameyang 11      NaN    NaN
# 83852  2019-20                           Kieran Tierney 515      NaN    NaN
# 83860  2019-20                            Edward Nketiah 13      NaN    NaN
# 83884  2019-20                Daniel Ceballos Fernández 469      NaN    NaN
# 83892  2019-20                               Pablo Marí 617      NaN    NaN
# ...
